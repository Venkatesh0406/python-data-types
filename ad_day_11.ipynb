# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkatesh0406/python/blob/main/ad_day_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2.4554,76.983,'hyd']

# %%
k
# Out:
# [4, 2.4554, 76.983, 'hyd']

# %%
pd.Series(k)
# Out:
# 0         4
# 1    2.4554
# 2    76.983
# 3       hyd
# dtype: object

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([38, 42, 40, 49, 37, 42, 35, 29, 41, 40, 41, 49, 31, 28, 39])

# %%
pd.Series(a)
# Out:
# 0     38
# 1     42
# 2     40
# 3     49
# 4     37
# 5     42
# 6     35
# 7     29
# 8     41
# 9     40
# 10    41
# 11    49
# 12    31
# 13    28
# 14    39
# dtype: int64

# %%
a[4:10]
# Out:
# array([37, 42, 35, 29, 41, 40])

# %%
s=pd.Series(a)

# %%
s
# Out:
# 0     38
# 1     42
# 2     40
# 3     49
# 4     37
# 5     42
# 6     35
# 7     29
# 8     41
# 9     40
# 10    41
# 11    49
# 12    31
# 13    28
# 14    39
# dtype: int64

# %%
s[4:10]
# Out:
# 4    37
# 5    42
# 6    35
# 7    29
# 8    41
# 9    40
# dtype: int64

# %%
b=np.random.randint(100,299,(6,5))

# %%
b
# Out:
# array([[114, 228, 264, 287, 285],
#        [159, 214, 208, 212, 233],
#        [212, 215, 246, 164, 164],
#        [140, 106, 166, 177, 170],
#        [178, 298, 118, 124, 154],
#        [241, 286, 175, 136, 102]])

# %%
b.ndim
# Out:
# 2

# %%
pd.DataFrame(b)
# Out:
#      0    1    2    3    4
# 0  114  228  264  287  285
# 1  159  214  208  212  233
# 2  212  215  246  164  164
# 3  140  106  166  177  170
# 4  178  298  118  124  154
# 5  241  286  175  136  102

# %%
df=pd.DataFrame(b,columns=['Roll','name','age','adds','country'])
df
# Out:
#    Roll  name  age  adds  country
# 0   114   228  264   287      285
# 1   159   214  208   212      233
# 2   212   215  246   164      164
# 3   140   106  166   177      170
# 4   178   298  118   124      154
# 5   241   286  175   136      102

# %%
df=pd.DataFrame(b,columns=['Roll','name','age','adds','country'],index=[182,183,185,186,187,188])
df
# Out:
#      Roll  name  age  adds  country
# 182   114   228  264   287      285
# 183   159   214  208   212      233
# 185   212   215  246   164      164
# 186   140   106  166   177      170
# 187   178   298  118   124      154
# 188   241   286  175   136      102

# %%
df.loc[182]
# Out:
# Roll       114
# name       228
# age        264
# adds       287
# country    285
# Name: 182, dtype: int64

# %%
df.iloc[0,0]
# Out:
# 114

# %%
df.loc[182,['Roll','name','age']]
# Out:
# Roll    114
# name    228
# age     264
# Name: 182, dtype: int64

# %%
df.iloc[[1,3,4]]
# Out:
#      Roll  name  age  adds  country
# 183   159   214  208   212      233
# 186   140   106  166   177      170
# 187   178   298  118   124      154

# %%
df.loc[[183,186,187]]
# Out:
#      Roll  name  age  adds  country
# 183   159   214  208   212      233
# 186   140   106  166   177      170
# 187   178   298  118   124      154

# %%
df.age
# Out:
# 182    264
# 183    208
# 185    246
# 186    166
# 187    118
# 188    175
# Name: age, dtype: int64

# %%
df[['age','adds']]
# Out:
#      age  adds
# 182  264   287
# 183  208   212
# 185  246   164
# 186  166   177
# 187  118   124
# 188  175   136
