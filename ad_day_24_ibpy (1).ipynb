# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv(r"/content/Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
len(cars)
# Out:
# 81

# %%
data = [12, 15, 14, 10, 18, 20, 22, 19, 15, 14, 13, 17, 21, 23, 24]
sns.histplot(data, kde=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = [12, 15, 14, 10, 18, 20, 22, 19, 15, 14, 13, 17, 21, 23, 24]

sns.boxplot(data=data)
plt.title('Box Plot')
plt.xlabel('Values')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.scatterplot(x='HP',y='SP',data=cars)
plt.xlabel('HP')
plt.ylabel('SP')
plt.title('scatter plot of HP vs SP')
plt.show()

# %%
# prompt: define scatterplot

import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.scatterplot(x='HP',y='MPG',data=cars) # Corrected column name to 'MPG'
plt.xlabel('Horsepower (HP)')
plt.ylabel('Miles Per Gallon (MPG)')
plt.title('Scatter Plot of Horsepower vs Miles Per Gallon')
plt.show()

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
import matplotlib.pyplot as plt
for col in cars.columns:
  if col != 'HP':
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='HP', y=col, data=cars)
    plt.title(f'Scatter Plot of HP vs {col}')
import matplotlib.pyplot as plt
for col in cars.columns:
  if col != 'HP':
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='HP', y=col, data=cars)
    plt.title(f'Scatter Plot of HP vs {col}')
    plt.xlabel('HP')
    plt.ylabel(col)
    plt.show()

# %%
# prompt: write a code for scatterplot of vol sp in simple code of python

import matplotlib.pyplot as plt
# Assuming 'cars' DataFrame is already loaded and available

plt.figure(figsize=(10,5))
sns.scatterplot(x='VOL', y='SP', data=cars)
plt.xlabel('VOL')
plt.ylabel('SP')
plt.title('Scatter Plot of VOL vs SP')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.scatterplot(x='VOL',y='WT',data=cars)
plt.xlabel('VOL')
plt.ylabel('WT')
plt.title('scatter plot of VOL vs WT')
plt.show()
